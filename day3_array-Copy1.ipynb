# %%
import numpy as np

# %%
sales=np.array([1500, 2000, 1800, 2500, 3000])
print(sales)
# Out:
# [1500 2000 1800 2500 3000]

# %%
print(np.sum(sales))
print(np.mean(sales))
print(np.max(sales))
print(np.min(sales))
# Out:
# 10800
# 2160.0
# 3000
# 1500

# %%
print("Addition:", sales+5)
print("subtraction:",sales-5)
print("multiplication:",sales*2)
print("division:", sales/2)
# Out:
# Addition: [1505 2005 1805 2505 3005]
# subtraction: [1495 1995 1795 2495 2995]
# multiplication: [3000 4000 3600 5000 6000]
# division: [ 750. 1000.  900. 1250. 1500.]
